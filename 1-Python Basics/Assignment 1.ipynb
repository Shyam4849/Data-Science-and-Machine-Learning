# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
user_input = int(input("Enter a number: "))
print(user_input)
# Out:
# 5

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
num = float(input("Enter a number: "))
if num < 0:
    print("Negative")
elif num > 0 :
    print("Positive")
else:
    print("Zero")
# Out:
# Positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))

if (num1 >= num2) and num1 >= num3:
    print(num1, " is largest")
elif (num2 >= num1) and (num2 >= num3):
    print(num2, " is largest")
elif (num3 >= num1) and (num3 >= num2):
    print(num3, " is largest")
# Out:
# 3.0  is largest

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
def factorial(n):
    if n==0:
        return 1
    else:
        return n * (factorial(n-1))

num = int(input("Enter a number: "))
print("The factorial of the number is: ", factorial(num))
# Out:
# The factorial of the number is:  120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
int_val = 12
float_val = 12.2
bool_val = True
string_val = "Shyam"

print(f"Integer Value: {int_val} and Type: {type(int_val)}")
print(f"Float Value: {float_val} and Type: {type(float_val)}")
print(f"Boolean Value: {bool_val} and Type: {type(bool_val)}")
print(f"String Value: {string_val} and Type: {type(string_val)}")
# Out:
# Integer Value: 12 and Type: <class 'int'>
# Float Value: 12.2 and Type: <class 'float'>
# Boolean Value: True and Type: <class 'bool'>
# String Value: Shyam and Type: <class 'str'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a = 12
b = 10

print(f"Before swapping: a={a} and b={b}")
a, b = b, a
print(f"After swapping: a={a} and b={b}")
# Out:
# Before swapping: a=12 and b=10
# After swapping: a=10 and b=12

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
celcius = float(input("Enter the temperature in celcius: "))

fahrenheit = (celcius * 9/5) + 32

print(f"Temperature in Fahrenheit is: {fahrenheit}")
# Out:
# Temperature in Fahrenheit is: 89.6

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
string1 = "Hello "
string2 = "World"

print(string1+string2)
# Out:
# Hello World

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
val = 32.3

if isinstance(val, float):
    print(val,"is float")
else:
    print(val, "is not float")
# Out:
# 32.3 is float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

print(f"Addition: {num1} + {num2} = {num1+num2}")
print(f"Subtraction: {num1} - {num2} = {num1-num2}")
print(f"Multiplication: {num1} * {num2} = {num1*num2}")
print(f"Division: {num1} / {num2} = {num1/num2}")
# Out:
# Addition: 10.0 + 2.0 = 12.0
# Subtraction: 10.0 - 2.0 = 8.0
# Multiplication: 10.0 * 2.0 = 20.0
# Division: 10.0 / 2.0 = 5.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = 3
b = 2

print(f"{a} == {b} : {a == b}")
print(f"{a} != {b} : {a != b}")
print(f"{a} > {b} : {a > b}")
print(f"{a} < {b} : {a < b}")
# Out:
# 3 == 2 : False
# 3 != 2 : True
# 3 > 2 : True
# 3 < 2 : False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
a = True
b = False

print(f"{a} and {b} : {a and b}")
print(f"{a} or {b} : {a or b}")
print(f"Not {a} : {not a}")
# Out:
# True and False : False
# True or False : True
# Not True : False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
a = float(input("Enter a number: "))

print(f"Square of the number is: {a**2}")
# Out:
# Square of the number is: 144.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
a = int(input("Enter a number: "))

if a%2 == 0:
    print(f"{a} is Even")
else:
    print(f"{a} is Odd")
# Out:
# 12 is Even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
num = int(input("Enter a number: "))

sum = (num * (num+1)) // 2

print(f"The sum of {num} natural number is: {sum}")
# Out:
# The sum of 10 natural number is: 55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = int(input("Enter the year: "))

if (year%4 == 0 and year%100 != 0) or year%400 == 0:
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# 2004 is a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
string = "Hey there"

reversed_string = string[::-1]
print(f"Reverse of {string} is: {reversed_string}")
# Out:
# Reverse of Hey there is: ereht yeH

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
string = "naman"

if string == string[::-1]:
    print(f"{string} is Palindrome")
else:
    print(f"{string} not a Palindrome")
# Out:
# naman is Palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
myList = [12,23,1,45,32,46,78]

myList.sort()
print(myList)

# myList.sort(reverse=True) # for Descending Order
# Out:
# [78, 46, 45, 32, 23, 12, 1]
