# %% [markdown]
# ### Importing Modules in Python: Modules and Packages
# In Python, modules and packages help organize and reuse code. Here's a comprehensive guide on how to import them.

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt, pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
print(sqrt(9))
print(pi)
# Out:
# 3.0
# 3.141592653589793

# %%
import package.maths

print(package.maths.addition(2,3))
# Out:
# 5

# %%
from package import maths
maths.addition(3,4)
# Out:
# 7
