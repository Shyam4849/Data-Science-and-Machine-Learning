# %% [markdown]
# #### Generators
# Generators are a simpler way to create iterators. They use the yield keyword to produce a series of values lazily, which means they generate values on the fly and do not store them in the memory.

# %%
def square(n):
    for i in range(3):
        yield i**2

# %%
square(3)
# Out:
# <generator object square at 0x00000134449CDAF0>

# %%
for i in square(3):
    print(i)
# Out:
# 0
# 1
# 4

# %%
a = square(3)
a
# Out:
# <generator object square at 0x00000134449B8740>

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 next(a)
#
# StopIteration:

# %%
def my_generator():
    yield 1
    yield 2
    yield 3

# %%
gen = my_generator()
gen
# Out:
# <generator object my_generator at 0x0000013444E74F20>

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
for val in gen:
    print(val)
# Out:
# 1
# 2
# 3

# %% [markdown]
# #### Practical: Reading Large Files
# Generators are particularly useful for reading large files because they allow you to process one line at a time without loading the entire file into memory.

# %%
# Practical: Reading large files

def read_large_file(file_path):
    with open(file_path,'r') as file:
        for line in file:
            yield line

# %%
file_path = 'large_file.txt'

for line in read_large_file(file_path):
    print(line.strip())
# Out:
# Droupadi Murmu is the 15th and current President of India, having taken office on July 25, 2022.
#
# Key details about the President of India:
#
# Role: Nominal head of the executive, holding the highest constitutional office.
#
# Term: Five years, residing at the Rashtrapati Bhavan in New Delhi.
#
# Background: Born in 1958 in Odisha, she has a background in education and local politics.
#
# Previous Holders: Notable predecessors include the first president, Dr. Rajendra Prasad, and the first female president, Pratibha Patil.
