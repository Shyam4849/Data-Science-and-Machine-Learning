# %% [markdown]
# ### The map() Function in Python
# The map() function applies a given function to all items in an input list (or any other iterable) and returns a map object (an iterator). This is particularly useful for transforming data in a list comprehensively.

# %%
def square(x):
    return x**2

square(10)
# Out:
# 100

# %%
numbers=[1,2,3,4,5,6,7,8]

list(map(square,numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
# lambda Function with map
numbers=[1,2,3,4,5,6,7,8]

list(map(lambda x:x*x, numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
# Map multiple iterables

numbers1=[1,2,3]
numbers2=[4,5,6]

added_numbers=list(map(lambda x,y: x+y, numbers1,numbers2))
print(added_numbers)
# Out:
# [5, 7, 9]

# %%
# map() to convert list of strings to integers

str_numbers = ['1','2','3','4','5']
int_numbers = list(map(int, str_numbers))

print(int_numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
words=['apples','banana','cherry']
upper_word = list(map(str.upper, words))
print(upper_word)
# Out:
# ['APPLES', 'BANANA', 'CHERRY']

# %%
def get_name(person):
    return person['name']

people=[
    {'name':'Shyam','age':32},
    {'name':'Oggy','age':15},
]
list(map(get_name, people))
# Out:
# ['Shyam', 'Oggy']

# %% [markdown]
# ### Conclusion
# The map() function is a powerful tool for applying transformation to iterable data structure. It can be used with regular functions, lambda, functions, and even multiple iterables, providing a versatile approach to data processing  in Python. By understanding an utilizing map(), you can write more effiicient and readable code.
