# %% [markdown]
# ### File Operation - Read and Write Files
# File handling is a crucial part of any programming language. Python provides built-in functions and methods to read and write to files, both text and binary. This lesson will cover the basics of file handling, including reading and writng text files and binary files.

# %%
# %whos
# Out:
# Variable   Type             Data/Info
# -------------------------------------
# file       TextIOWrapper    <_io.TextIOWrapper name='<...>de='a' encoding='cp1252'>
# lines      list             n=3

# %%
# Read a whole file

with open('example.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# Hello How are you?
# I am fine
# Shyam this side
# Happy Learning

# %%
# Read a file line by line

with open('example.txt','r') as file:
    for line in file:
        print(line.strip()) # .strip() removes the newline character
# Out:
# Hello How are you?
#
# I am fine
#
# Shyam this side
#
# Happy Learning

# %%
# Writing a file(Overwriting)

with open('example.txt','w') as file:
    file.write('Hello World!!\n')
    file.write('this is a new line.')

# %%
# Write a file(without Overwriting)

with open('example.txt','a') as file:
    file.write("\nAppend operation taking place")

# %%
# Writing a list of lines to a file

lines = ['First line\n','Second line\n', 'Third line\n']
with open('example.txt','a') as file:
    file.writelines(lines)
