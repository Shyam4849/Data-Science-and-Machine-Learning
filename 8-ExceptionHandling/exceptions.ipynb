# %% [markdown]
# ### Understanding Exceptions
# Exception Handling in Python allows you to handle errors gracefully and take corrective actions without stoppig the execution of the program. This lesson will cover the basics of exceptions, including how to use try except, else, and finally blocks.

# %% [markdown]
# ### What are Exceptions?
# Exceptions are events that disrupt the noraml flow of a program. They occur when an error is encountered during program execution. Common exceptions include:
# * ZeroDivisionError: Dividing by zero
# * FileNotFoundError: File not found
# * ValueError: Invalid value
# * TypeError: Invalid type

# %%
# Exception try, except block

try:
    a=b # * b is not defined so it might give an exception -> put it in the try block
except:
    print("The variable has not been assigned")
# Out:
# The variable has not been assigned

# %%
a=b # ! b is not defined so it gives error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a=b # ! b is not defined so it gives error
#
# NameError: name 'b' is not defined

# %%
try:  
    a=b
    
except NameError as ex: # * way to handle only the NameError exception
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    result = 1/0
except ZeroDivisionError as ex: # * way to handle only the ZeroDivisionError exception
    print(ex)
    print("Please enter the denominator greater than 0")
# Out:
# division by zero
# Please enter the denominator greater than 0

# %%
try:
    result = 1/2 # * Does not give any exception
    a=b # ! Gives an NameError exception
except ZeroDivisionError as ex: # * Handles only the ZeroDivisionError Exception -> gives a NameError
    print(ex)
    print("Please enter the denominator greater than 0")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 try:
#       2     result = 1/2 # * Does not give any exception
# ----> 3     a=b # ! Gives an NameError exception
#       4 except ZeroDivisionError as ex: # * Handles only the ZeroDivisionError Exception
#       5     print(ex)
#
# NameError: name 'b' is not defined

# %%
try:
    result = 1/2
    a = b # ! NameError Exception
except ZeroDivisionError as ex: # * For ZeroDivisionError
    print(ex)

# * Always use this at the end of all the exceptions as it the parent class from which all the exceptions are getting derived
except Exception as ex1: # ? Exception handles all the types of exception
    print(ex1)
    print("Main exception got caught here")
# Out:
# name 'b' is not defined
# Main exception got caught here

# %%
try:
    num=int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater than 0")
except Exception as ex:
    print(ex)
# Out:
# This is not a valid number

# %%
# try, except, else block
try:
    num = int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("Enter denominator greater than 0")
except Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
# Out:
# Enter denominator greater than 0

# %%
# try, except, else and finally
try:
    num = int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("You cannot divide by zero")
except Exception as ex:
    print(ex)
else: # Only gets executed when exception is not there
    print(f"The result is {result}")
finally: # Gets executed even the exception is there
    print("Execution Completed")
# Out:
# You cannot divide by zero
# Execution Completed

# %%
# File Handling and Exception Handling

try:
    file=open('example.txt','r')
    content = file.read()
    a=b
    print(content)
except FileNotFoundError:
    print("The file doesnot exists")
except Exception as ex:
    print(ex)
finally:
    if 'file' in locals() or file.closed():
        file.close()
        print("file closed")
# Out:
# name 'b' is not defined
# file closed
